# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : san patricio
# Processing Record 2 of Set 1 : butembo
# Processing Record 3 of Set 1 : qaanaaq
# Processing Record 4 of Set 1 : provideniya
# Processing Record 5 of Set 1 : albany
# Processing Record 6 of Set 1 : longyearbyen
# Processing Record 7 of Set 1 : vaini
# Processing Record 8 of Set 1 : tuatapere
# City not found. Skipping...
# Processing Record 9 of Set 1 : asfi
# Processing Record 10 of Set 1 : atikokan
# Processing Record 11 of Set 1 : rikitea
# Processing Record 12 of Set 1 : cabo san lucas
# Processing Record 13 of Set 1 : hami
# Processing Record 14 of Set 1 : new norfolk
# Processing Record 15 of Set 1 : neiafu
# City not found. Skipping...
# Processing Record 16 of Set 1 : cherskiy
# Processing Record 17 of Set 1 : thompson
# Processing Record 18 of Set 1 : bathsheba
# Processing Record 19 of Set 1 : xuchang
# Processing Record 20 of Set 1 : hasaki
# Processing Record 21 of Set 1 : east london
# Processing Record 22 of Set 1 : walvis bay
# Processing Record 23 of Set 1 : wairoa
# Processing Record 24 of Set 1 : georgetown
# Processing Record 25 of Set 1 : luderitz
# Processing Record 26 of Set 1 : ancud
# Processing Record 27 of Set 1 : kapaa
# Processing Record 28 of Set 1 : faanui
# City not found. Skipping...
# Processing Record 29 of Set 1 : bolobo
# Processing Record 30 of Set 1 : castro
# Processing Record 31 of Set 1 : laguna
# Processing Record 32 of Set 1 : jamestown
# Processing Record 33 of Set 1 : qasigiannguit
# City not found. Skipping...
# Processing Record 34 of Set 1 : avarua
# Processing Record 35 of Set 1 : bambous virieux
# Processing Record 36 of Set 1 : north bend
# Processing Record 37 of Set 1 : imeni poliny osipenko
# Processing Record 38 of Set 1 : coahuayana
# City not found. Skipping...
# Processing Record 39 of Set 1 : carnarvon
# Processing Record 40 of Set 1 : ushuaia
# Processing Record 41 of Set 1 : port elizabeth
# Processing Record 42 of Set 1 : udachnyy
# Processing Record 43 of Set 1 : dunedin
# Processing Record 44 of Set 1 : mahebourg
# Processing Record 45 of Set 1 : cape town
# Processing Record 46 of Set 1 : vila velha
# Processing Record 47 of Set 1 : busselton
# Processing Record 48 of Set 1 : altay
# Processing Record 49 of Set 1 : ixtapa
# Processing Record 50 of Set 1 : punta arenas
# Processing Record 0 of Set 2 : cap malheureux
# Processing Record 1 of Set 2 : hilo
# Processing Record 2 of Set 2 : petauke
# Processing Record 3 of Set 2 : gorgan
# Processing Record 4 of Set 2 : khani
# Processing Record 5 of Set 2 : hervey bay
# Processing Record 6 of Set 2 : kampot
# Processing Record 7 of Set 2 : bluff
# Processing Record 8 of Set 2 : biak
# Processing Record 9 of Set 2 : muyezerskiy
# Processing Record 10 of Set 2 : souillac
# Processing Record 11 of Set 2 : nemuro
# Processing Record 12 of Set 2 : namibe
# Processing Record 13 of Set 2 : barrow
# Processing Record 14 of Set 2 : mandalgovi
# Processing Record 15 of Set 2 : yellowknife
# Processing Record 16 of Set 2 : hobyo
# Processing Record 17 of Set 2 : woodward
# Processing Record 18 of Set 2 : atuona
# Processing Record 19 of Set 2 : roberval
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 5 : derzhavinsk
# Processing Record 13 of Set 5 : moyale
# Processing Record 14 of Set 5 : byron bay
# Processing Record 15 of Set 5 : kingsville
# Processing Record 16 of Set 5 : yabrud
# Processing Record 17 of Set 5 : yenotayevka
# Processing Record 18 of Set 5 : husavik
# Processing Record 19 of Set 5 : tiznit
# Processing Record 20 of Set 5 : saint-felicien
# Processing Record 21 of Set 5 : buala
# Processing Record 22 of Set 5 : san felipe
# Processing Record 23 of Set 5 : mianyang
# Processing Record 24 of Set 5 : half moon bay
# City not found. Skipping...
# Processing Record 25 of Set 5 : labuhan
# Processing Record 26 of Set 5 : ahuatempan
# Processing Record 27 of Set 5 : vostok
# Processing Record 28 of Set 5 : acapulco
# Processing Record 29 of Set 5 : nicolas bravo
# City not found. Skipping...
# Processing Record 30 of Set 5 : nadvoitsy
# Processing Record 31 of Set 5 : itarema
# Processing Record 32 of Set 5 : hamilton
# Processing Record 33 of Set 5 : petropavlovsk-kamchatskiy
# Processing Record 34 of Set 5 : tigre
# City not found. Skipping...
# Processing Record 35 of Set 5 : nelson bay
# Processing Record 36 of Set 5 : kandi
# Processing Record 37 of Set 5 : bahia blanca
# Processing Record 38 of Set 5 : shirokiy
# Processing Record 39 of Set 5 : pacific grove
# Processing Record 40 of Set 5 : saint george
# Processing Record 41 of Set 5 : kaitangata
# Processing Record 42 of Set 5 : bom jesus
# City not found. Skipping...
# Processing Record 43 of Set 5 : guiren
# Processing Record 44 of Set 5 : shanting
# Processing Record 45 of Set 5 : bethel
# Processing Record 46 of Set 5 : trinidad
# Processing Record 47 of Set 5 : corner brook
# Processing Record 48 of Set 5 : kavieng
# Processing Record 49 of Set 5 : okha
# Processing Record 50 of Set 5 : brikama
# Processing Record 0 of Set 6 : ferme-neuve
# Processing Record 1 of Set 6 : fortuna
# Processing Record 2 of Set 6 : bengkulu
# Processing Record 3 of Set 6 : aleksandrov gay
# Processing Record 4 of Set 6 : ipora
# Processing Record 5 of Set 6 : pemangkat
# Processing Record 6 of Set 6 : riyadh
# Processing Record 7 of Set 6 : rundu
# Processing Record 8 of Set 6 : kaya
# City not found. Skipping...
# Processing Record 9 of Set 6 : pokhara
# Processing Record 10 of Set 6 : arica
# Processing Record 11 of Set 6 : amahai
# Processing Record 12 of Set 6 : kloulklubed
# Processing Record 13 of Set 6 : forquilhinha
# Processing Record 14 of Set 6 : sitka
# Processing Record 15 of Set 6 : tommot
# Processing Record 16 of Set 6 : yulara
# Processing Record 17 of Set 6 : brae
# Processing Record 18 of Set 6 : cidreira
# Processing Record 19 of Set 6 : sur
# Processing Record 20 of Set 6 : biltine
# Processing Record 21 of Set 6 : codrington
# Processing Record 22 of Set 6 : fairbanks
# Processing Record 23 of Set 6 : barra do garcas
# Processing Record 24 of Set 6 : eureka
# Processing Record 25 of Set 6 : banjar
# Processing Record 26 of Set 6 : podor
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 6 : santa cruz do capibaribe
# Processing Record 28 of Set 6 : qingyuan
# Processing Record 29 of Set 6 : havoysund
# Processing Record 30 of Set 6 : lowicz
# Processing Record 31 of Set 6 : kandrian
# Processing Record 32 of Set 6 : amapa
# Processing Record 33 of Set 6 : mangan
# Processing Record 34 of Set 6 : puerto leguizamo
# Processing Record 35 of Set 6 : tungor
# Processing Record 36 of Set 6 : ambon
# Processing Record 37 of Set 6 : guerrero negro
# Processing Record 38 of Set 6 : honghu
# Processing Record 39 of Set 6 : oschersleben
# City not found. Skipping...
# Processing Record 40 of Set 6 : skibbereen
# Processing Record 41 of Set 6 : sioux lookout
# Processing Record 42 of Set 6 : darhan
# Processing Record 43 of Set 6 : manzhouli
# Processing Record 44 of Set 6 : sungaipenuh
# Processing Record 45 of Set 6 : seminole
# Processing Record 46 of Set 6 : cockburn town
# Processing Record 47 of Set 6 : roma
# Processing Record 48 of Set 6 : tutoia
# Processing Record 49 of Set 6 : channel-port aux basques
# Processing Record 50 of Set 6 : sigulda
# Processing Record 0 of Set 7 : panji
# Processing Record 1 of Set 7 : narsaq
# Processing Record 2 of Set 7 : paamiut
# Processing Record 3 of Set 7 : si satchanalai
# Processing Record 4 of Set 7 : nikolayevka
# Processing Record 5 of Set 7 : agadez
# Processing Record 6 of Set 7 : iqaluit
# Processing Record 7 of Set 7 : airai
# Processing Record 8 of Set 7 : visby
# Processing Record 9 of Set 7 : atar
# Processing Record 10 of Set 7 : port lincoln
# Processing Record 11 of Set 7 : luena
# Processing Record 12 of Set 7 : ratnagiri
# Processing Record 13 of Set 7 : amuntai
# Processing Record 14 of Set 7 : eastbourne
# Processing Record 15 of Set 7 : esperance
# Processing Record 16 of Set 7 : clarence town
# Processing Record 17 of Set 7 : port macquarie
# Processing Record 18 of Set 7 : cody
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 7 : pattani
# Processing Record 20 of Set 7 : beberibe
# Processing Record 21 of Set 7 : minab
# Processing Record 22 of Set 7 : bara
# Processing Record 23 of Set 7 : puerto ayacucho
# Processing Record 24 of Set 7 : constitucion
# Processing Record 25 of Set 7 : olinda
# Processing Record 26 of Set 7 : fethiye
# Processing Record 27 of Set 7 : sao filipe
# City not found. Skipping...
# Processing Record 28 of Set 7 : severo-kurilsk
# Processing Record 29 of Set 7 : aksarka
# Processing Record 30 of Set 7 : dali
# Processing Record 31 of Set 7 : kirakira
# Processing Record 32 of Set 7 : amberley
# Processing Record 33 of Set 7 : namatanai
# Processing Record 34 of Set 7 : antalaha
# Processing Record 35 of Set 7 : trincomalee
# Processing Record 36 of Set 7 : caravelas
# Processing Record 37 of Set 7 : ilulissat
# Processing Record 38 of Set 7 : gamba
# Processing Record 39 of Set 7 : rovenki
# Processing Record 40 of Set 7 : angoche
# Processing Record 41 of Set 7 : urumqi
# Processing Record 42 of Set 7 : beyneu
# Processing Record 43 of Set 7 : boromo
# Processing Record 45 of Set 11 : ahipara
# Processing Record 46 of Set 11 : itaituba
# Processing Record 47 of Set 11 : chicama
# Processing Record 48 of Set 11 : aosta
# Processing Record 49 of Set 11 : alice springs
# Processing Record 50 of Set 11 : bambanglipuro
# Processing Record 0 of Set 12 : alta floresta
# Processing Record 1 of Set 12 : bairiki
# City not found. Skipping...
# Processing Record 2 of Set 12 : saint anthony
# Processing Record 3 of Set 12 : provost
# Processing Record 4 of Set 12 : whitehaven
# Processing Record 5 of Set 12 : portland
# Processing Record 6 of Set 12 : manggar
# Processing Record 7 of Set 12 : christchurch
# Processing Record 8 of Set 12 : magaria
# Processing Record 9 of Set 12 : kotri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
weather_data.count()
# Out:
# City          570
# Cloudiness    570
# Country       570
# Date          570
# Humidity      570
# Lat           570
# Lng           570
# Max Temp      570
# Wind Speed    570
# dtype: int64

# %%
weather_data
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    San Patricio          75      US  1603654394        69  28.02  -97.52
# 1         Butembo         100      CD  1603654394       100   0.15   29.28
# 2         Qaanaaq         100      GL  1603654394        80  77.48  -69.36
# 3     Provideniya         100      RU  1603654394        91  64.38 -173.30
# 4          Albany           0      US  1603654159        43  42.60  -73.97
# ..            ...         ...     ...         ...       ...    ...     ...
# 565      Portland          20      US  1603654338        28  45.52 -122.68
# 566       Manggar         100      ID  1603654475        81  -2.88  108.27
# 567  Christchurch         100      NZ  1603654475        93 -43.53  172.63
# 568       Magaria          64      NE  1603654475        20  13.00    8.91
# 569         Kotri           0      PK  1603654475        29  25.37   68.31
#
#      Max Temp  Wind Speed
# 0       84.99       14.99
# 1       59.74        2.51
# 2       12.72       12.08
# 3       33.21        3.65
# 4       48.99        5.82
# ..        ...         ...
# 565     46.00       17.22
# 566     80.94        6.31
# 567     54.00       12.75
# 568     83.07        6.06
# 569     77.85        8.30
#
# [570 rows x 9 columns]

# %%
# Save as csv
weather_data.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# create scatter plot latitude vs temperature
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], facecolor = "lightsteelblue", edgecolor = "black")

# Set labels
plt.title("Latitude of Cities vs Maximum Temperature")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha =0.5)

print("Temperature is at it's highest around 0 latitude. As the latitude increases, temperature has a significant drop")
# Out:
# Temperature is at it's highest around 0 latitude. As the latitude increases, temperature has as significant drop

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# create scatter plot latitude vs humidity
plt.scatter(weather_data["Lat"], weather_data["Humidity"], facecolor = "lightsteelblue", edgecolor = "black")

# Set labels
plt.title("Latitude of Cities vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-', linewidth=1, alpha =0.5)

print("Humidity seems to be more prominent North of the equator but overall there doesn't seem to be a perfect trend. ")
# Out:
# Humidity seems to be more prominent North of the equator but overall there doesn't seem to be a perfect trend.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# create scatter plot latitude vs cloudiness
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], facecolor = "lightsteelblue", edgecolor = "black")

# Set labels
plt.title("Latitude of Cities vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(linestyle='-', linewidth=1, alpha =0.5)

print("There is no coorelation between latitude and cloudiness")
# Out:
# There is no coorelation between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# create scatter plot latitude vs Wind speed
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], facecolor = "lightsteelblue", edgecolor = "black")

# Set labels
plt.title("Latitude of Cities vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.grid(linestyle='-', linewidth=1, alpha =0.5)

print("Latitude isn't the same across the board when it comes to wind speed. Some latitudes have very different wind speed.")
# Out:
# Latitude isn't the same across the board when it comes to wind speed. Some latitudes have very different wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# Seperate Northern and Southern Hemisphere figures
northern_hemisphere = weather_data.loc[weather_data["Lat"] >= 0]
southern_hemisphere = weather_data.loc[weather_data["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
annotate(equation, 0, 0)

# Set a labels
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the image
plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

print("There is a prominent negative coorelation between max temperature and latitude in the Northern Hemisphere.")
# Out:
# The r-squared is : -0.88
# There is a prominent negative coorelation between max temperature and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"])
annotate(equation, -30, 50)

# Set a labels
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the image
plt.savefig("Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

print("There is a fairly strong positive coorelation between max temperature and latitude in the Southern Hemisphere.")
# Out:
# The r-squared is : 0.75
# There is a fairly strong positive coorelation between max temperature and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])
annotate(equation, 40, 15)

# Set a labels
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the image
plt.savefig("Images/Northern Hemisphere - Humidity vs. Latitude Linear Regression.png")

print("There is a fairly strong positive coorelation between humidity and latitude in the Northern Hemisphere.")
# Out:
# The r-squared is : 0.33
# There is a fairly strong positive coorelation between humidity and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])
annotate(equation, -55, 40)

# Set a labels
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the image
plt.savefig("Images/Southern Hemisphere - Humidity vs. Latitude Linear Regression.png")

print("There doesn't seem to be much coorelation at all between humidity and latitude in the Southern Hemisphere.")
# Out:
# The r-squared is : -0.07
# There doesn't seem to be much coorelation at all between humidity and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])
annotate(equation, 40, 27)

# Set a labels
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the image
plt.savefig("Images/Northern Hemisphere - Cloudiness vs. Latitude Linear Regression.png")

print("There is a small positive coorelation between cloudiness and latitude in the Northern Hemisphere.")
# Out:
# The r-squared is : 0.13
# There is a small positive coorelation between cloudiness and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])
annotate(equation, -55, 20)

# Set a labels
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the image
plt.savefig("Images/Southern Hemisphere - Cloudiness vs. Latitude Linear Regression.png")

print("There is a small positive coorelation between cloudiness and latitude in the Southern Hemisphere.")
# Out:
# The r-squared is : 0.14
# There is a small positive coorelation between cloudiness and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])
annotate(equation, 0, 35)

# Set a labels
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# Save the image
plt.savefig("Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")

print("There is a small positive coorelation between wind speed and latitude in the Northern Hemisphere.")
# Out:
# The r-squared is : 0.22
# There is a small positive coorelation between wind speed and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])
annotate(equation, -22, 25)

# Set a labels
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# Save the image
plt.savefig("Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")

print("There is a small negative coorelation between cloudiness and latitude in the Southern Hemisphere.")
# Out:
# The r-squared is : -0.12
# There is a small negative coorelation between cloudiness and latitude in the Southern Hemisphere.
