# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : nouadhibou
# Processing Record 2 of Set 1 : vaini
# Processing Record 3 of Set 1 : hermanus
# Processing Record 4 of Set 1 : asau
# Processing Record 5 of Set 1 : punta arenas
# Processing Record 6 of Set 1 : iisalmi
# Processing Record 7 of Set 1 : georgetown
# Processing Record 8 of Set 1 : pevek
# Processing Record 9 of Set 1 : bahia blanca
# Processing Record 10 of Set 1 : butaritari
# Processing Record 11 of Set 1 : mapiripan
# Processing Record 12 of Set 1 : dunedin
# Processing Record 13 of Set 1 : trelew
# Processing Record 14 of Set 1 : bredasdorp
# Processing Record 15 of Set 1 : mataura
# Processing Record 16 of Set 1 : waingapu
# Processing Record 17 of Set 1 : ucluelet
# Processing Record 18 of Set 1 : rikitea
# Processing Record 19 of Set 1 : hithadhoo
# Processing Record 20 of Set 1 : tasiilaq
# Processing Record 21 of Set 1 : charters towers
# Processing Record 22 of Set 1 : bluff
# Processing Record 23 of Set 1 : half moon bay
# Processing Record 24 of Set 1 : severo-kurilsk
# Processing Record 25 of Set 1 : torbay
# Processing Record 26 of Set 1 : kodiak
# Processing Record 27 of Set 1 : oistins
# Processing Record 28 of Set 1 : kapaa
# Processing Record 29 of Set 1 : clyde river
# Processing Record 30 of Set 1 : kita
# Processing Record 31 of Set 1 : busselton
# Processing Record 32 of Set 1 : petrila
# Processing Record 33 of Set 1 : bouza
# Processing Record 34 of Set 1 : jamestown
# Processing Record 35 of Set 1 : sao filipe
# Processing Record 36 of Set 1 : saint anthony
# Processing Record 37 of Set 1 : ushuaia
# City not found. Skipping...
# Processing Record 38 of Set 1 : mar del plata
# Processing Record 39 of Set 1 : goma
# Processing Record 40 of Set 1 : dafeng
# Processing Record 41 of Set 1 : richards bay
# Processing Record 42 of Set 1 : nome
# Processing Record 43 of Set 1 : srednekolymsk
# Processing Record 44 of Set 1 : nikolskoye
# Processing Record 45 of Set 1 : sola
# City not found. Skipping...
# Processing Record 46 of Set 1 : port hawkesbury
# Processing Record 47 of Set 1 : port alfred
# Processing Record 48 of Set 1 : bonavista
# Processing Record 49 of Set 1 : avarua
# Processing Record 50 of Set 1 : molteno
# Processing Record 0 of Set 2 : bose
# Processing Record 1 of Set 2 : narsaq
# City not found. Skipping...
# Processing Record 2 of Set 2 : chokurdakh
# Processing Record 3 of Set 2 : mahebourg
# Processing Record 4 of Set 2 : apatin
# City not found. Skipping...
# Processing Record 5 of Set 2 : sistranda
# City not found. Skipping...
# Processing Record 6 of Set 2 : barrow
# City not found. Skipping...
# Processing Record 7 of Set 2 : saint-philippe
# Processing Record 8 of Set 2 : albany
# Processing Record 9 of Set 2 : sao raimundo das mangabeiras
# Processing Record 10 of Set 2 : araouane
# Processing Record 11 of Set 2 : atuona
# Processing Record 12 of Set 2 : thompson
# City not found. Skipping...
# Processing Record 13 of Set 2 : faanui
# Processing Record 14 of Set 2 : varkkallai
# Processing Record 15 of Set 2 : nuevo progreso
# Processing Record 16 of Set 2 : sattahip
# Processing Record 17 of Set 2 : san andres
# Processing Record 18 of Set 2 : saint george
# Processing Record 19 of Set 2 : egvekinot
# Processing Record 20 of Set 2 : surin
# Processing Record 21 of Set 2 : pangnirtung
# Processing Record 22 of Set 2 : fukue
# Processing Record 23 of Set 2 : castro
# Processing Record 24 of Set 2 : katsuura
# Processing Record 25 of Set 2 : sortova
# Processing Record 26 of Set 2 : muyuka
# Processing Record 27 of Set 2 : los llanos de aridane
# Processing Record 28 of Set 2 : antofagasta
# Processing Record 29 of Set 2 : qaanaaq
# Processing Record 30 of Set 2 : laguna
# City not found. Skipping...
# Processing Record 31 of Set 2 : westport
# Processing Record 32 of Set 2 : paso de los toros
# Processing Record 33 of Set 2 : zvishavane
# Processing Record 34 of Set 2 : nantucket
# Processing Record 35 of Set 2 : vila franca do campo
# Processing Record 36 of Set 2 : abu kamal
# City not found. Skipping...
# Processing Record 37 of Set 2 : port elizabeth
# Processing Record 38 of Set 2 : kurilsk
# Processing Record 39 of Set 2 : pyapon
# Processing Record 40 of Set 2 : iqaluit
# City not found. Skipping...
# Processing Record 41 of Set 2 : paducah
# Processing Record 42 of Set 2 : plettenberg bay
# Processing Record 43 of Set 2 : angoche
# Processing Record 44 of Set 2 : mladenovac
# Processing Record 45 of Set 2 : gumdag
# Processing Record 46 of Set 2 : moindou
# Processing Record 47 of Set 2 : antalaha
# Processing Record 48 of Set 2 : luderitz
# Processing Record 49 of Set 2 : vila
# Processing Record 50 of Set 2 : cape town
# Processing Record 0 of Set 3 : maridi
# Processing Record 1 of Set 3 : provideniya
# Processing Record 2 of Set 3 : korla
# Processing Record 3 of Set 3 : avera
# Processing Record 4 of Set 3 : mathathane
# City not found. Skipping...
# Processing Record 5 of Set 3 : east london
# Processing Record 6 of Set 3 : agadez
# City not found. Skipping...
# Processing Record 7 of Set 3 : kavaratti
# Processing Record 8 of Set 3 : coihaique
# Processing Record 9 of Set 3 : gizo
# Processing Record 10 of Set 3 : viedma
# Processing Record 11 of Set 3 : codrington
# Processing Record 12 of Set 3 : saskylakh
# Processing Record 13 of Set 3 : salym
# Processing Record 14 of Set 3 : sinfra
# Processing Record 15 of Set 3 : hobart
# Processing Record 16 of Set 3 : kargasok
# Processing Record 17 of Set 3 : tuktoyaktuk
# Processing Record 18 of Set 3 : dolores
# City not found. Skipping...
# Processing Record 19 of Set 3 : new norfolk
# Processing Record 20 of Set 3 : adrar
# Processing Record 21 of Set 3 : lufilufi
# Processing Record 22 of Set 3 : corinto
# Processing Record 23 of Set 3 : saint-francois
# Processing Record 24 of Set 3 : mahon
# Processing Record 25 of Set 3 : karagach
# Processing Record 26 of Set 3 : te anau
# Processing Record 27 of Set 3 : bingol
# Processing Record 28 of Set 3 : sarangani
# Processing Record 29 of Set 3 : bethel
# Processing Record 30 of Set 3 : sabha
# Processing Record 31 of Set 3 : nileshwar
# Processing Record 32 of Set 3 : makurdi
# Processing Record 0 of Set 5 : thomaston
# Processing Record 1 of Set 5 : waitati
# Processing Record 2 of Set 5 : margate
# Processing Record 3 of Set 5 : mattawa
# Processing Record 4 of Set 5 : sorland
# Processing Record 5 of Set 5 : karratha
# Processing Record 6 of Set 5 : cabo san lucas
# Processing Record 7 of Set 5 : george
# Processing Record 8 of Set 5 : namibe
# Processing Record 9 of Set 5 : cheremshan
# Processing Record 10 of Set 5 : lavrentiya
# Processing Record 11 of Set 5 : amapa
# Processing Record 12 of Set 5 : beloha
# City not found. Skipping...
# Processing Record 13 of Set 5 : kaitangata
# Processing Record 14 of Set 5 : palmer
# Processing Record 15 of Set 5 : hambantota
# Processing Record 16 of Set 5 : sitka
# Processing Record 17 of Set 5 : stokmarknes
# Processing Record 18 of Set 5 : fereydun kenar
# Processing Record 19 of Set 5 : iranduba
# Processing Record 20 of Set 5 : ilulissat
# Processing Record 21 of Set 5 : cidreira
# Processing Record 22 of Set 5 : constitucion
# Processing Record 23 of Set 5 : nanortalik
# Processing Record 24 of Set 5 : terney
# Processing Record 25 of Set 5 : worthington
# Processing Record 26 of Set 5 : mayskiy
# Processing Record 27 of Set 5 : baghdad
# Processing Record 28 of Set 5 : aksarka
# Processing Record 29 of Set 5 : tulagi
# Processing Record 30 of Set 5 : cherskiy
# Processing Record 31 of Set 5 : bengkulu
# Processing Record 32 of Set 5 : taguatinga
# Processing Record 33 of Set 5 : venice
# Processing Record 34 of Set 5 : kloulklubed
# Processing Record 35 of Set 5 : carnarvon
# Processing Record 36 of Set 5 : kisesa
# City not found. Skipping...
# Processing Record 37 of Set 5 : vila velha
# Processing Record 38 of Set 5 : beidao
# Processing Record 39 of Set 5 : maldonado
# Processing Record 40 of Set 5 : hokitika
# Processing Record 41 of Set 5 : nanpara
# Processing Record 42 of Set 5 : alwar
# Processing Record 43 of Set 5 : satinka
# City not found. Skipping...
# Processing Record 44 of Set 5 : leningradskiy
# Processing Record 45 of Set 5 : aasiaat
# Processing Record 46 of Set 5 : brandon
# Processing Record 47 of Set 5 : makakilo city
# City not found. Skipping...
# Processing Record 48 of Set 5 : cochrane
# Processing Record 49 of Set 5 : hofn
# Processing Record 50 of Set 5 : olafsvik
# Processing Record 0 of Set 6 : namatanai
# Processing Record 1 of Set 6 : katherine
# Processing Record 2 of Set 6 : umba
# Processing Record 3 of Set 6 : lorengau
# Processing Record 4 of Set 6 : buala
# Processing Record 5 of Set 6 : bambous virieux
# Processing Record 6 of Set 6 : high level
# Processing Record 7 of Set 6 : beira
# Processing Record 8 of Set 6 : niamey
# Processing Record 9 of Set 6 : abashiri
# Processing Record 10 of Set 6 : yeppoon
# Processing Record 11 of Set 6 : hobyo
# Processing Record 12 of Set 6 : gillette
# Processing Record 13 of Set 6 : saldanha
# Processing Record 14 of Set 6 : kupang
# Processing Record 15 of Set 6 : kattivakkam
# Processing Record 16 of Set 6 : huarmey
# Processing Record 17 of Set 6 : bubaque
# Processing Record 18 of Set 6 : sambava
# City not found. Skipping...
# Processing Record 19 of Set 6 : bulgan
# Processing Record 20 of Set 6 : grenfell
# Processing Record 21 of Set 6 : chuy
# Processing Record 22 of Set 6 : nabire
# Processing Record 23 of Set 6 : saint-louis
# Processing Record 24 of Set 6 : lima
# Processing Record 25 of Set 6 : ambilobe
# Processing Record 26 of Set 6 : rochegda
# Processing Record 27 of Set 6 : sergeyevka
# Processing Record 28 of Set 6 : lady lake
# Processing Record 29 of Set 6 : itoman
# Processing Record 30 of Set 6 : totma
# City not found. Skipping...
# Processing Record 31 of Set 6 : geraldton
# Processing Record 32 of Set 6 : la asuncion
# Processing Record 33 of Set 6 : alta floresta
# City not found. Skipping...
# Processing Record 34 of Set 6 : vestmannaeyjar
# Processing Record 35 of Set 6 : ayan
# Processing Record 36 of Set 6 : akom
# Processing Record 37 of Set 6 : mandalgarh
# City not found. Skipping...
# Processing Record 38 of Set 6 : kavieng
# Processing Record 39 of Set 6 : san patricio
# Processing Record 40 of Set 6 : manta
# Processing Record 41 of Set 6 : shache
# Processing Record 42 of Set 6 : poum
# Processing Record 43 of Set 6 : las palmas
# Processing Record 44 of Set 6 : shelburne
# Processing Record 45 of Set 6 : hibbing
# Processing Record 46 of Set 6 : tuatapere
# Processing Record 47 of Set 6 : whitehorse
# Processing Record 48 of Set 6 : beringovskiy
# Processing Record 49 of Set 6 : port hedland
# Processing Record 50 of Set 6 : itarema
# Processing Record 0 of Set 7 : touros
# Processing Record 1 of Set 7 : hirado
# Processing Record 2 of Set 7 : qasigiannguit
# Processing Record 3 of Set 7 : marigot
# Processing Record 4 of Set 7 : berlevag
# Processing Record 5 of Set 7 : jalu
# Processing Record 6 of Set 7 : bousso
# City not found. Skipping...
# Processing Record 7 of Set 7 : yulara
# Processing Record 8 of Set 7 : vostok
# Processing Record 9 of Set 7 : qandala
# Processing Record 10 of Set 7 : pacific grove
# City not found. Skipping...
# Processing Record 11 of Set 7 : tabat
# Processing Record 12 of Set 7 : esperance
# Processing Record 13 of Set 7 : hauterive
# Processing Record 14 of Set 7 : oliveira do bairro
# Processing Record 15 of Set 7 : knysna
# Processing Record 16 of Set 7 : padang
# City not found. Skipping...
# Processing Record 17 of Set 7 : sadasivpet
# Processing Record 18 of Set 7 : mount holly
# Processing Record 19 of Set 7 : belmonte
# Processing Record 20 of Set 7 : salekhard
# Processing Record 21 of Set 7 : chino valley
# Processing Record 22 of Set 7 : staraya kulatka
# Processing Record 23 of Set 7 : nemuro
# Processing Record 24 of Set 7 : bonfim
# Processing Record 25 of Set 7 : sao joao da barra
# Processing Record 26 of Set 7 : marsh harbour
# Processing Record 27 of Set 7 : cachoeira do sul
# Processing Record 28 of Set 7 : portland
# Processing Record 29 of Set 7 : muros
# Processing Record 30 of Set 7 : buchanan
# Processing Record 31 of Set 7 : smithers
# Processing Record 32 of Set 7 : severo-yeniseyskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
weather_data.count()
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
weather_data
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Nouadhibou           0      MR  1604110234        88  20.93  -17.03
# 1           Vaini          40      TO  1604110235        69 -21.20 -175.20
# 2        Hermanus           0      ZA  1604110117        69 -34.42   19.23
# 3            Asău         100      RO  1604110235        97  46.43   26.40
# 4    Punta Arenas          75      CL  1604110055        66 -53.15  -70.92
# ..            ...         ...     ...         ...       ...    ...     ...
# 542      Rehoboth          90      NA  1604110073        29 -23.32   17.08
# 543           Kez         100      RU  1604110307        94  57.90   53.72
# 544   San Antonio           1      US  1604110028        50  29.42  -98.49
# 545      Necochea           0      AR  1604110307        72 -38.55  -58.74
# 546        Marzuq           0      YE  1604110307        47  14.40   46.47
#
#      Max Temp  Wind Speed
# 0       66.20       13.87
# 1       78.80       13.87
# 2       53.01       11.86
# 3       42.01        4.18
# 4       50.00       10.29
# ..        ...         ...
# 542     63.93        4.90
# 543     34.18        7.34
# 544     60.80        3.40
# 545     51.01        8.01
# 546     62.96        3.36
#
# [547 rows x 9 columns]

# %%
# Save as csv
weather_data.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# create scatter plot latitude vs temperature
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], facecolor = "lightsteelblue", edgecolor = "black")

# Set labels
plt.title("Latitude of Cities vs Maximum Temperature")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha =0.5)

# Save the image
plt.savefig("Images/Latitude vs. Temperature.png")

print("Temperature is at it's highest around 0 latitude. As the latitude increases, temperature has a significant drop")
# Out:
# Temperature is at it's highest around 0 latitude. As the latitude increases, temperature has a significant drop

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# create scatter plot latitude vs humidity
plt.scatter(weather_data["Lat"], weather_data["Humidity"], facecolor = "lightsteelblue", edgecolor = "black")

# Set labels
plt.title("Latitude of Cities vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-', linewidth=1, alpha =0.5)

# Save the image
plt.savefig("Images/Latitude Vs. Humidity.png")

print("Humidity seems to be more prominent North of the equator but overall there doesn't seem to be a perfect trend. ")
# Out:
# Humidity seems to be more prominent North of the equator but overall there doesn't seem to be a perfect trend.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# create scatter plot latitude vs cloudiness
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], facecolor = "lightsteelblue", edgecolor = "black")

# Set labels
plt.title("Latitude of Cities vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(linestyle='-', linewidth=1, alpha =0.5)

# Save the image
plt.savefig("Images/Latitude Vs. Cloudiness.png")

print("There is no coorelation between latitude and cloudiness")
# Out:
# There is no coorelation between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# create scatter plot latitude vs Wind speed
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], facecolor = "lightsteelblue", edgecolor = "black")

# Set labels
plt.title("Latitude of Cities vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.grid(linestyle='-', linewidth=1, alpha =0.5)

# Save the image
plt.savefig("Images/Latitude Vs. Wind Speed.png")

print("Latitude isn't the same across the board when it comes to wind speed. Some latitudes have very different wind speed.")
# Out:
# Latitude isn't the same across the board when it comes to wind speed. Some latitudes have very different wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# Seperate Northern and Southern Hemisphere figures
northern_hemisphere = weather_data.loc[weather_data["Lat"] >= 0]
southern_hemisphere = weather_data.loc[weather_data["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
annotate(equation, 0, 0)

# Set a labels
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the image
plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

print("There is a prominent negative coorelation between max temperature and latitude in the Northern Hemisphere.")
# Out:
# The r-squared is : -0.89
# There is a prominent negative coorelation between max temperature and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"])
annotate(equation, -30, 50)

# Set a labels
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the image
plt.savefig("Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

print("There is a fairly strong positive coorelation between max temperature and latitude in the Southern Hemisphere.")
# Out:
# The r-squared is : 0.68
# There is a fairly strong positive coorelation between max temperature and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])
annotate(equation, 40, 15)

# Set a labels
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the image
plt.savefig("Images/Northern Hemisphere - Humidity vs. Latitude Linear Regression.png")

print("There is a fairly strong positive coorelation between humidity and latitude in the Northern Hemisphere.")
# Out:
# The r-squared is : 0.25
# There is a fairly strong positive coorelation between humidity and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])
annotate(equation, -55, 40)

# Set a labels
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the image
plt.savefig("Images/Southern Hemisphere - Humidity vs. Latitude Linear Regression.png")

print("There doesn't seem to be much coorelation at all between humidity and latitude in the Southern Hemisphere.")
# Out:
# The r-squared is : 0.08
# There doesn't seem to be much coorelation at all between humidity and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])
annotate(equation, 40, 27)

# Set a labels
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the image
plt.savefig("Images/Northern Hemisphere - Cloudiness vs. Latitude Linear Regression.png")

print("There is a small positive coorelation between cloudiness and latitude in the Northern Hemisphere.")
# Out:
# The r-squared is : 0.18
# There is a small positive coorelation between cloudiness and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])
annotate(equation, -55, 20)

# Set a labels
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the image
plt.savefig("Images/Southern Hemisphere - Cloudiness vs. Latitude Linear Regression.png")

print("There is a small positive coorelation between cloudiness and latitude in the Southern Hemisphere.")
# Out:
# The r-squared is : 0.17
# There is a small positive coorelation between cloudiness and latitude in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])
annotate(equation, 0, 35)

# Set a labels
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# Save the image
plt.savefig("Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")

print("There is a small positive coorelation between wind speed and latitude in the Northern Hemisphere.")
# Out:
# The r-squared is : 0.12
# There is a small positive coorelation between wind speed and latitude in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Equation 
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])
annotate(equation, -22, 25)

# Set a labels
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")

# Save the image
plt.savefig("Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")

print("There is a small negative coorelation between cloudiness and latitude in the Southern Hemisphere.")
# Out:
# The r-squared is : -0.32
# There is a small negative coorelation between cloudiness and latitude in the Southern Hemisphere.
